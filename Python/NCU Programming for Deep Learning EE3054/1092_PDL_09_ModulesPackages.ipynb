# %% [raw]
# Bill Lubanovic (2019). Introducing Python: Modern Computing in Simple Packages. Chapter 11

# %% [markdown]
# # Modules, Packages, and Goodies

# %% [markdown]
# The text of this book is organized in a hierarchy: words, sentences, paragraphs, and chapters.

# %% [markdown]
# Code has a roughly similar bottom-up organization:
# * data types are like words
# * expressions and statements are like sentences
# * functions are like paragraphs
# * modules are like chapters

# %% [markdown]
# ## Modules and the import Statement

# %% [markdown]
# A module is just a file of any Python code.

# %% [markdown]
# You don't need to do anything special - any Python code can be used as a module by others

# %% [markdown]
# ## Import a Module

# %% [markdown]
# The simplest use of the import statement is *import module*, where module is the name of another Python file, without the .py extension

# %%
# fast.py
# from random import choice
# places = ['McDonalds', 'KFC', 'Burger King', 
#    'Taco Bell', 'Wendys', 'Arbys', 'Pizza Hut']
# def pick(): # see the docstring below
#    "Return random fast food place"
#    return choice(places)

# %% [markdown]
# Importing random within the pick( ) function instead of at the top of the file. Like many aspects of programming, use the style that seems the most clear to you. The module-qualified name (random.choice) is safer but requires a little more typing

# %%
# fast2.py
# places = ['McDonalds', 'KFC', 'Burger King', 
#    'Taco Bell', 'Wendys', 'Arbys', 'Pizza Hut']
# def pick(): 
#    import random
#    return random.choice(places)

# %% [markdown]
# We imported the entire fast module but needed to use fast as prefix to pick( ). After this import statement, everything in fast.py is available to the main program, as long as we tack fast. before its name.

# %%
import fast
place = fast.pick()
print("Let's go to", place)
# Out:
# Let's go to Burger King

# %% [markdown]
# ## Import a Module with Another Name

# %%
import fast as f
place = f.pick()
print("Let's go to", place)
# Out:
# Let's go to Burger King

# %% [markdown]
# ## Import Only What You Want from a Module

# %%
from fast import pick
place = pick()
print("Let's go to", place)
# Out:
# Let's go to Arbys

# %%
from fast import pick as who_cares
place = who_cares()
print("Let's go to", place)
# Out:
# Let's go to Wendys

# %% [markdown]
# ## Packages

# %% [markdown]
# A package is just a subdirectory that contains .py files. And you can go more than one level deep, with directories inside those

# %% [markdown]
# If your version of Python is earlier than 3.3, you'll need one of more thing in the sources subdirectory to make it a Python package: a file named \_\_init\_\_.py. This can be an empty file, but pre-3.3 Python needs it to treat the directory containing it as a package.

# %% [markdown]
# (Now make a subdirectory named choices and put two modules in it - fast.py and advice.py)

# %%
# choices/fast.py
# from random import choice
# places = ['McDonalds', 'KFC', 'Burger King', 
#    'Taco Bell', 'Wendys', 'Arbys', 'Pizza Hut']
# def pick(): 
#    "Return random fast food place"
#    return choice(places)

# %%
# choices/advice.py
# from random import choice
# answers = ['Yes', 'No', 'Reply hazy', 'Sorry, what?']
# def give(): 
#    """ Return random advice """
#    return choice(answers)

# %%
# Run in your current directory, not in sources
from choices import fast, advice

print("Let's go to", fast.pick())
print("Should we take out?", advice.give())
# Out:
# Let's go to KFC
# Should we take out? Sorry, what?

# %% [markdown]
# ## The Module Search Path

# %% [markdown]
# To see all the places that your Python interpreter looks, import the standard sys module and use its path list. This is a list of directory names and ZIP archive files that Python searches in order to find modules to import

# %%
import sys
for place in sys.path:
    print(place)
# Out:
# /Users/lunghaolee/Documents/NCU/Course/PDL/1092
# /Users/lunghaolee/Documents/anaconda3/lib/python37.zip
# /Users/lunghaolee/Documents/anaconda3/lib/python3.7
# /Users/lunghaolee/Documents/anaconda3/lib/python3.7/lib-dynload
#
# /Users/lunghaolee/Documents/anaconda3/lib/python3.7/site-packages
# /Users/lunghaolee/Documents/anaconda3/lib/python3.7/site-packages/aeosa
# /Users/lunghaolee/Documents/anaconda3/lib/python3.7/site-packages/IPython/extensions
# /Users/lunghaolee/.ipython

# %% [markdown]
# The blank output line is the empty string '', which stands for the current directory. If '' is first in sys.path, Python looks in the current directory first when you try to import something

# %% [markdown]
# The first match will be used. This means that if you define a module named random and it's in the search path before the standard library, you won't be able to access the standard library's random now

# %% [markdown]
# You can modify the search path within your code

# %%
import sys
sys.path.insert(0, "/xmy/modules")

# %%
import sys
for place in sys.path:
    print(place)
# Out:
# /xmy/modules
# /Users/lunghaolee/Documents/NCU/Course/PDL/1092
# /Users/lunghaolee/Documents/anaconda3/lib/python37.zip
# /Users/lunghaolee/Documents/anaconda3/lib/python3.7
# /Users/lunghaolee/Documents/anaconda3/lib/python3.7/lib-dynload
#
# /Users/lunghaolee/Documents/anaconda3/lib/python3.7/site-packages
# /Users/lunghaolee/Documents/anaconda3/lib/python3.7/site-packages/aeosa
# /Users/lunghaolee/Documents/anaconda3/lib/python3.7/site-packages/IPython/extensions
# /Users/lunghaolee/.ipython

# %% [markdown]
# ## Relative and Absolute Imports

# %% [markdown]
# So far, we imported our own modules from:
# * The current directory
# * The subdirectory
# * The Python standard library

# %% [markdown]
# Python supports absolute or relative imports
# * You can import it ralative to your location with from . import xxx
# * If it's in the directory above you, from .. import xxx
# * If it's under a sibling directory called abc, from ..abc import xxx

# %% [markdown]
# The . and .. notation was borrowed from Unix's shorthand for current directory and parent directory

# %% [markdown]
# ## Namespace Packages

# %% [markdown]
# You've seen that you can package Python modules as
# * A single module (.py file)
# * A package (directory containing modules, and possibly other packages)

# %% [raw]
# critters
#   - rougarou.py
#   - wendigo.py

# %% [markdown]
# You can also split a package across directories with namespace packages
# * Make new location directiories above critters
# * Make cousion critters directories under these new parents
# * Move existing modules to their respective directories

# %% [raw]
# north
#   - critters
#       - wendigo.py
# south
#   - critters
#       - rougarou.py

# %% [markdown]
# from critters import wendigo, rougarou

# %% [markdown]
# ## Modules Verus Objects

# %% [markdown]
# All the classes, functions, and global variables in a module are available to the outside.

# %% [markdown]
# Objects can use properties and "dunder" (\_\_ ...) naming to hide or control access to their data attributes

# %% [markdown]
# ## Goodies in the Python Standard Library

# %% [markdown]
# One of Python's prominent claims is that is has "butteries included" -- a large standard library of modules that perform many useful tasks.

# %% [markdown]
# When you're about to write some Python code, it's often worthwhile to first check whether there's a standard module that already does what you want.

# %% [markdown]
# ### Handle Missing Keys with setdefault( ) and defaultdict( )

# %% [markdown]
# Using the dictionary get( ) function to return a default value avoids an exception. The setdefault( ) function is like get( ), but also assigns an item to the dictionary if the key is missing

# %%
periodic_table = {'Hydrogen': 1, 'Helium': 2}
periodic_table
# Out:
# {'Hydrogen': 1, 'Helium': 2}

# %% [markdown]
# If the key was not already in the dictionary, the new value is used

# %%
carbon = periodic_table.setdefault('Carbon', 12)
carbon
# Out:
# 12

# %%
periodic_table
# Out:
# {'Hydrogen': 1, 'Helium': 2, 'Carbon': 12}

# %% [markdown]
# If we try to assign a different default value to an existing key, the original value is returned and nothing is changed.

# %%
helium = periodic_table.setdefault('Helium', 947)
helium
# Out:
# 2

# %%
periodic_table
# Out:
# {'Hydrogen': 1, 'Helium': 2, 'Carbon': 12}

# %% [markdown]
# defaultdict( ) is similar, but specifies the default value for any new key up front, when the dictionary is created.

# %%
from collections import defaultdict
periodic_table = defaultdict(int) # Its argument is a function

# %% [markdown]
# Now any missing value will be an integer (int), with the value 0

# %%
periodic_table['Hydrogen'] = 1

# %%
periodic_table['Lead']
# Out:
# 0

# %%
periodic_table
# Out:
# defaultdict(int, {'Hydrogen': 1, 'Lead': 0})

# %% [markdown]
# The argument to defaultdict() is a function that returns the value to be assigned to a missing key.

# %%
from collections import defaultdict

# %%
def no_idea():
    return 'Huh?'

# %%
bestiary = defaultdict(no_idea)

# %%
bestiary['A'] = 'Abominable Snowman'
bestiary['B'] = 'Basilisk'

# %%
bestiary['A']
# Out:
# 'Abominable Snowman'

# %%
bestiary['B']
# Out:
# 'Basilisk'

# %%
bestiary['C']
# Out:
# 'Huh?'

# %% [markdown]
# You can use the functions int( ), list( ), or dict( ) to return default empty values for those types: int( ) returns 0, list( ) returns any empty list ([ ]), and dict( ) returns an empty dictionary({ }). If you omit the argument, the initial value of a new key will be set to None.

# %% [markdown]
# By the way, you can use lambda to define your default-making function right inside the call

# %%
bestiary = defaultdict(lambda: 'Huh?')

# %%
bestiary['E']
# Out:
# 'Huh?'

# %% [markdown]
# Using int is one way to make your own counter

# %%
from collections import defaultdict
food_counter = defaultdict(int)
for food in ['spam', 'spam', 'eggs', 'spam']:
    food_counter[food] += 1

# %%
for food, count in food_counter.items():
    print(food, count)
# Out:
# spam 3
# eggs 1

# %% [markdown]
# If food_counter had been a normal dictionary instead of a defaultdict, Python would have raised an exception every time we tried to increment the dictionary element food_counter[food] because it would not have been initialized

# %% [markdown]
# We wolud have needed to do some extra work

# %%
dict_counter = { }
for food in ['spam', 'spam', 'eggs', 'spam']:
    if not food in dict_counter:
        dict_counter[food] = 0 
    dict_counter[food] += 1

# %%
for food, count in food_counter.items():
    print(food, count)
# Out:
# spam 3
# eggs 1

# %% [markdown]
# ### Count items with Counter( )

# %%
from collections import Counter
breakfast = ['spam', 'spam', 'eggs', 'spam']
breakfast_counter = Counter(breakfast)
breakfast_counter
# Out:
# Counter({'spam': 3, 'eggs': 1})

# %% [markdown]
# The most_common( ) function returns all elements in descending order, or just the top count elements if given a count

# %%
breakfast_counter.most_common()
# Out:
# [('spam', 3), ('eggs', 1)]

# %%
breakfast_counter.most_common(1)
# Out:
# [('spam', 3)]

# %% [markdown]
# The first way we combine the two counters is by addition, using +

# %%
breakfast_counter
# Out:
# Counter({'spam': 3, 'eggs': 1})

# %%
lunch = ['eggs', 'eggs', 'bacon']
lunch_counter  = Counter(lunch)

# %%
lunch_counter
# Out:
# Counter({'eggs': 2, 'bacon': 1})

# %%
breakfast_counter + lunch_counter
# Out:
# Counter({'spam': 3, 'eggs': 3, 'bacon': 1})

# %% [markdown]
# As you might expect, you substract one counter from another by using -

# %%
# What's for breakfast but not for lunch?
breakfast_counter - lunch_counter
# Out:
# Counter({'spam': 3})

# %%
# What we can have for lunch that we can't have for breakfast?
lunch_counter - breakfast_counter
# Out:
# Counter({'eggs': 1, 'bacon': 1})

# %% [markdown]
# You can get common items by using the intersection operator &

# %% [markdown]
# The intersection chose the common element with the lower count

# %%
breakfast_counter & lunch_counter
# Out:
# Counter({'eggs': 1})

# %% [markdown]
# You can get all items by using the union operator |

# %% [markdown]
# Unlike addition, union didn't add their counts, but selected the one with the larger count

# %%
breakfast_counter | lunch_counter
# Out:
# Counter({'spam': 3, 'eggs': 2, 'bacon': 1})

# %% [markdown]
# ### Order by Key with OrderedDict( )

# %% [raw]
# Starting with Python 3.7, dictionaries retain keys in the order in which they were added. OrderedDict is useful for earlier versions, which have an unpredictable order.

# %%
quotes = {
    'Moe': 'A wise guy, huh?',
    'Larry': 'Ow!',
    'Curly': 'Nyuk nyuk!',
}
for stooge in quotes:
    print(stooge)
# Out:
# Moe
# Larry
# Curly

# %% [markdown]
# An OrderedDict( ) remembers the order of key addition and returns them in the same order from an iterator

# %%
from collections import OrderedDict
quotes = OrderedDict([
    ('Moe', 'A wise guy, huh?'),
    ('Larry', 'Ow!'),
    ('Curly', 'Nyuk nyuk!'),
])
for stooge in quotes:
    print(stooge)
# Out:
# Moe
# Larry
# Curly

# %% [markdown]
# ### Stack + Queue = deque

# %% [markdown]
# A deque is a double-ended queue, which has features of both a stack and a queue. It's useful when you want to add and delete items from either end of a sequence. The function popleft( ) removes the leftmost item from the deque and return it; pop( ) removes the rightmost item and returns it.

# %% [markdown]
# We work from both ends of a word to the middle to see whether it's a palindrome

# %%
def palindrome(word):
    from collections import deque
    dq = deque(word)
    while len(dq) > 1:
        if dq.popleft() != dq.pop():
            return False
    return True

# %%
palindrome('a')
# Out:
# True

# %%
palindrome('racecar')
# Out:
# True

# %%
palindrome('')
# Out:
# True

# %%
palindrome('radar')
# Out:
# True

# %%
palindrome('halibut')
# Out:
# False

# %% [markdown]
# If you really wanted a quick palindrome checker, it would be a lot simpler to just compare a string with its reverse

# %%
def another_palindrome(word):
    return word == word[::-1]

# %%
another_palindrome('radar')
# Out:
# True

# %%
another_palindrome('halibut')
# Out:
# False

# %% [markdown]
# ### Iterate over Code Structures with itertools

# %% [markdown]
# itertools contains special-purpose iterator functions. Each returns one item at a time when called within a for ... in loop, and remembers its state between calls

# %% [markdown]
# chain( ) runs through its argument as though they were a single interable

# %%
import itertools
for item in itertools.chain([1, 2], ['a', 'b']):
    print(item)
# Out:
# 1
# 2
# a
# b

# %% [markdown]
# cycle( ) is an infinite iterator, cycling through its arguments

# %%
import itertools
for item in itertools.cycle([1, 2]):
    print(item)
# Out:
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# ...

# %% [markdown]
# accumulate( ) calculates accumulated values. By default, it calculates the sum

# %%
import itertools
for item in itertools.accumulate([1, 2, 3, 4]):
    print(item)
# Out:
# 1
# 3
# 6
# 10

# %% [markdown]
# You can provide a function as the second argument to accumulate( ), and it will be used instead of addition

# %%
import itertools
def multiply(a, b):
    return a * b

for item in itertools.accumulate([1, 2, 3, 4], multiply):
    print(item)
# Out:
# 1
# 2
# 6
# 24

# %% [markdown]
# ### Print Nicely with pprint( )

# %% [markdown]
# All of our examples have used print( ) (or just the variable name, in the interactive interpreter) to print things. Sometimes, the results are hard to read. We need a pretty printer such as pprint( )

# %%
from collections import OrderedDict
quotes = OrderedDict([
    ('Moe', 'A wise guy, huh?'),
    ('Larry', 'Ow!'),
    ('Curly', 'Nyuk nyuk!'),
])

# %%
print(quotes)
# Out:
# OrderedDict([('Moe', 'A wise guy, huh?'), ('Larry', 'Ow!'), ('Curly', 'Nyuk nyuk!')])

# %%
from pprint import pprint
pprint(quotes)
# Out:
# OrderedDict([('Moe', 'A wise guy, huh?'),
#              ('Larry', 'Ow!'),
#              ('Curly', 'Nyuk nyuk!')])

# %% [markdown]
# ### Get Random

# %% [markdown]
# random.choice returns a value from the sequence (list, tuple, dictionary, string) argument that it's given

# %%
from random import choice
choice([23, 9, 46, 'bacon', 0x123abc])
# Out:
# 46

# %%
choice(('a', 'one', 'and-a', 'two'))
# Out:
# 'and-a'

# %%
choice(range(100))
# Out:
# 49

# %%
choice('alphabet')
# Out:
# 'a'

# %% [markdown]
# Use the sample( ) function to get more than one value at a time

# %%
from random import sample
sample([23, 9 , 46, 'bacon', 0x123abc], 3)
# Out:
# [9, 46, 23]

# %%
sample(('a', 'one', 'and-a', 'two'), 2)
# Out:
# ['and-a', 'one']

# %%
sample(range(100), 4)
# Out:
# [31, 93, 65, 84]

# %%
sample('alphabet', 7)
# Out:
# ['a', 'b', 'e', 'l', 'p', 'h', 't']

# %% [markdown]
# To get a random integer from any range, you can use choice( ) or sample( ) with range( ), or use randint( ) or randrange( )

# %%
from random import randint
randint(38, 74)
# Out:
# 72

# %%
randint(38, 74)
# Out:
# 53

# %%
randint(38, 74)
# Out:
# 69

# %% [markdown]
# randrange( ), like range( ), has arguments for the start (inclusive) and end (exclusive) integers, and an optional integer step

# %%
from random import randrange
randrange(38, 74)
# Out:
# 46

# %%
randrange(38, 74, 10)
# Out:
# 48

# %%
randrange(38, 74, 10)
# Out:
# 68

# %% [markdown]
# Get a random real number (a float) between 0.0 and 1.0

# %%
from random import random

# %%
random()
# Out:
# 0.8103360212869837

# %%
random()
# Out:
# 0.06958858215983077

# %%
random()
# Out:
# 0.944673726713492
