# %% [markdown]
# # Requests: HTTP for Humans™

# %% [markdown]
# https://requests.readthedocs.io/en/master/

# %% [markdown]
# Requests is an elegant and simple HTTP library for Python, built for human begins

# %% [markdown]
# Requests allows you to send HTTP/1.1 requests extremely easily. There’s no need to manually add query strings to your URLs, or to form-encode your POST data.

# %% [markdown]
# First, make sure that Requests is installed.

# %%
import requests

# %%
requests.__version__
# Out:
# '2.22.0'

# %% [markdown]
# ![9SYCUdM9MS65A7nH2ETZKKd6.png](attachment:9SYCUdM9MS65A7nH2ETZKKd6.png)

# %% [markdown]
# ## Make a Request

# %% [markdown]
# Making a request with Requests is very simple.

# %%
r = requests.get('http://api.github.com/events')

# %%
type(r)
# Out:
# requests.models.Response

# %% [markdown]
# Now, we have a Response object called r. We can get all the information we need from this object.

# %% [markdown]
# Requests' simple API means that all forms of HTTP request are as obvious

# %% [markdown]
# This is how you make an HTTP POST request

# %%
r = requests.post('https://httpbin.org/post', data={'key':'value'})

# %% [markdown]
# ## Passing Parameters in URLs

# %% [markdown]
# You often want to send some sort of data in the URL’s query string. If you were constructing the URL by hand, this data would be given as key/value pairs in the URL after a question mark, e.g. httpbin.org/get?key=val.

# %% [markdown]
# Requests allows you to provide these arguments as a dictionary of strings, using the params keyword argument

# %% [markdown]
# As an example, if you wanted to pass key1=value1 and key2=value2 to httpbin.org/get, you would use the following code:

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get('https://httpbin.org/get', params = payload)

# %% [markdown]
# You can see that the URL has been correctly encoded by printing the URL

# %%
print(r.url)
# Out:
# https://httpbin.org/get?key1=value1&key2=value2

# %% [markdown]
# Note that any dictionary key whose value is None will not be added to the URL's query string

# %% [markdown]
# You can also pass a list of items as a value

# %%
payload = {'key1': 'value1', 'key2': ['value2', 'value3']}
r = requests.get('https://httpbin.org/get', params=payload)

# %%
print(r.url)
# Out:
# https://httpbin.org/get?key1=value1&key2=value2&key2=value3

# %% [markdown]
# ## Response Content

# %% [markdown]
# We can read the content of the server’s response

# %%
import requests 
r = requests.get('https://api.github.com/events')

# %%
r.text
# Out:
# '[{"id":"15850120575","type":"PushEvent","actor":{"id":2234830,"login":"gregmacfarlane","display_login":"gregmacfarlane","gravatar_id":"","url":"https://api.github.com/users/gregmacfarlane","avatar_url":"https://avatars.githubusercontent.com/u/2234830?"},"repo":{"id":308447129,"name":"byu-transpolab/wheelchair_cdap2","url":"https://api.github.com/repos/byu-transpolab/wheelchair_cdap2"},"payload":{"push_id":6866294569,"size":4,"distinct_size":4,"ref":"refs/heads/master","head":"884d7a8ad246d58883c59793c018750a732a5278","before":"5da7f077127567995e26b8b70610d5300da71ca8","commits":[{"sha":"aa3d427077ff5005d77d3ad99de6eca3ec2a1f3f","author":{"email":"gregmacfarlane@byu.edu","name":"Greg Macfarlane"},"message":"Rename project file","distinct":true,"url":"https://api.github.com/repos/byu-transpolab/wheelchair_cdap2/commits/aa3d427077ff5005d77d3ad99de6eca3ec2a1f3f"},{"sha":"56c418c0dfe53f8d96480a2acbbbf9378ca54dda","author":{"email":"gregmacfarlane@byu.edu","name":"Greg Macfarlane"},"message":"Rename project title and build website","distinct":true,"url":"https://api.github.com/repos/byu-transpolab/wheelchair_cdap2/commits/56c418c0dfe53f8d96480a2acbbbf9378ca54dda"},{"sha":"f65f47ba23c9b31ca95e18cb202152796c185dfd","author":{"email":"gregmacfarlane@byu.edu","name":"Greg Macfarlane"},"message":"Begin the script to process the activities data from NHTS","distinct":true,"url":"https://api.github.com/repos/byu-transpolab/wheelchair_cdap2/commits/f65f47ba23c9b31ca95e18cb202152796c185dfd"},{"sha":"884d7a8ad246d58883c59793c018750a732a5278","author":{"email":"gregmacfarlane@byu.edu","name":"Greg Macfarlane"},"message":"Assemble data frame for estimation\\n\\nSome additional variables will be necessary for the paper, but that\'s what we\'ve got.","distinct":true,"url":"https://api.github.com/repos/byu-transpolab/wheelchair_cdap2/commits/884d7a8ad246d58883c59793c018750a732a5278"}]},"public":true,"created_at":"2021-04-07T16:04:53Z","org":{"id":55851450,"login":"byu-transpolab","gravatar_id":"","url":"https://api.github.com/orgs/byu-transpolab","avatar_url":"https://avatars.githubusercontent.com/u/55851450?"}},{"id":"15850120576","type":"PushEvent","actor":{"id":63485082,"login":"techyminati","display_login":"techyminati","gravatar_id":"","url":"https://api.github.com/users/techyminati","avatar_url":"https://avatars.githubusercontent.com/u/63485082?"},"repo":{"id":323880427,"name":"RealmeFirmwareUpdater/aosp-workflow","url":"https://api.github.com/repos/RealmeFirmwareUpdater/aosp-workflow"},"payload":{"push_id":6866294580,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"a7800aebd868a6ce80189fb6c10a11dc1ebb7f45","before":"936f38aca38bb0b78d2349b52b5027e3841e1327","commits":[{"sha":"a7800aebd868a6ce80189fb6c10a11dc1ebb7f45","author":{"email":"aospbot@techyminati.com","name":"AOSP_BOT"},"message":"Workflow : Loop","distinct":true,"url":"https://api.github.com/repos/RealmeFirmwareUpdater/aosp-workflow/commits/a7800aebd868a6ce80189fb6c10a11dc1ebb7f45"}]},"public":true,"created_at":"2021-04-07T16:04:53Z","org":{"id":76481347,"login":"RealmeFirmwareUpdater","gravatar_id":"","url":"https://api.github.com/orgs/RealmeFirmwareUpdater","avatar_url":"https://avatars.githubusercontent.com/u/76481347?"}},{"id":"15850120578","type":"CreateEvent","actor":{"id":10810283,"login":"direwolf-github","display_login":"direwolf-github","gravatar_id":"","url":"https://api.github.com/users/direwolf-github","avatar_url":"https://avatars.githubusercontent.com/u/10810283?"},"repo":{"id":355606000,"name":"direwolf-github/ephemeral-ci-4ac1a4fa","url":"https://api.github.com/repos/direwolf-github/ephemeral-ci-4ac1a4fa"},"payload":{"ref":"branch-d198ce0b","ref_type":"branch","master_branch":"master","description":null,"pusher_type":"user"},"public":true,"created_at":"2021-04-07T16:04:53Z"},{"id":"15850120572","type":"PullRequestEvent","actor":{"id":6329406,"login":"Babacooll","display_login":"Babacooll","gravatar_id":"","url":"https://api.github.com/users/Babacooll","a ...

# %% [markdown]
# Requests will automatically decode content from the server. Most unicode charsets are seamlessly decoded.

# %% [markdown]
# When you make a request, Requests makes educated guesses about the encoding of the response based on the HTTP headers. The text encoding guessed by Requests is used when you access r.text.

# %% [markdown]
# You can find out what encoding Requests is using, and change it, using the r.encoding property:

# %%
r.encoding
# Out:
# 'utf-8'

# %%
r.encoding = 'ISO-8859-1'
r.encoding
# Out:
# 'ISO-8859-1'

# %% [markdown]
# ## Binary Response Content

# %% [markdown]
# You can also access the response body as bytes, for non-text requests:

# %%
r.content
# Out:
# b'[{"id":"15850120575","type":"PushEvent","actor":{"id":2234830,"login":"gregmacfarlane","display_login":"gregmacfarlane","gravatar_id":"","url":"https://api.github.com/users/gregmacfarlane","avatar_url":"https://avatars.githubusercontent.com/u/2234830?"},"repo":{"id":308447129,"name":"byu-transpolab/wheelchair_cdap2","url":"https://api.github.com/repos/byu-transpolab/wheelchair_cdap2"},"payload":{"push_id":6866294569,"size":4,"distinct_size":4,"ref":"refs/heads/master","head":"884d7a8ad246d58883c59793c018750a732a5278","before":"5da7f077127567995e26b8b70610d5300da71ca8","commits":[{"sha":"aa3d427077ff5005d77d3ad99de6eca3ec2a1f3f","author":{"email":"gregmacfarlane@byu.edu","name":"Greg Macfarlane"},"message":"Rename project file","distinct":true,"url":"https://api.github.com/repos/byu-transpolab/wheelchair_cdap2/commits/aa3d427077ff5005d77d3ad99de6eca3ec2a1f3f"},{"sha":"56c418c0dfe53f8d96480a2acbbbf9378ca54dda","author":{"email":"gregmacfarlane@byu.edu","name":"Greg Macfarlane"},"message":"Rename project title and build website","distinct":true,"url":"https://api.github.com/repos/byu-transpolab/wheelchair_cdap2/commits/56c418c0dfe53f8d96480a2acbbbf9378ca54dda"},{"sha":"f65f47ba23c9b31ca95e18cb202152796c185dfd","author":{"email":"gregmacfarlane@byu.edu","name":"Greg Macfarlane"},"message":"Begin the script to process the activities data from NHTS","distinct":true,"url":"https://api.github.com/repos/byu-transpolab/wheelchair_cdap2/commits/f65f47ba23c9b31ca95e18cb202152796c185dfd"},{"sha":"884d7a8ad246d58883c59793c018750a732a5278","author":{"email":"gregmacfarlane@byu.edu","name":"Greg Macfarlane"},"message":"Assemble data frame for estimation\\n\\nSome additional variables will be necessary for the paper, but that\'s what we\'ve got.","distinct":true,"url":"https://api.github.com/repos/byu-transpolab/wheelchair_cdap2/commits/884d7a8ad246d58883c59793c018750a732a5278"}]},"public":true,"created_at":"2021-04-07T16:04:53Z","org":{"id":55851450,"login":"byu-transpolab","gravatar_id":"","url":"https://api.github.com/orgs/byu-transpolab","avatar_url":"https://avatars.githubusercontent.com/u/55851450?"}},{"id":"15850120576","type":"PushEvent","actor":{"id":63485082,"login":"techyminati","display_login":"techyminati","gravatar_id":"","url":"https://api.github.com/users/techyminati","avatar_url":"https://avatars.githubusercontent.com/u/63485082?"},"repo":{"id":323880427,"name":"RealmeFirmwareUpdater/aosp-workflow","url":"https://api.github.com/repos/RealmeFirmwareUpdater/aosp-workflow"},"payload":{"push_id":6866294580,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"a7800aebd868a6ce80189fb6c10a11dc1ebb7f45","before":"936f38aca38bb0b78d2349b52b5027e3841e1327","commits":[{"sha":"a7800aebd868a6ce80189fb6c10a11dc1ebb7f45","author":{"email":"aospbot@techyminati.com","name":"AOSP_BOT"},"message":"Workflow : Loop","distinct":true,"url":"https://api.github.com/repos/RealmeFirmwareUpdater/aosp-workflow/commits/a7800aebd868a6ce80189fb6c10a11dc1ebb7f45"}]},"public":true,"created_at":"2021-04-07T16:04:53Z","org":{"id":76481347,"login":"RealmeFirmwareUpdater","gravatar_id":"","url":"https://api.github.com/orgs/RealmeFirmwareUpdater","avatar_url":"https://avatars.githubusercontent.com/u/76481347?"}},{"id":"15850120578","type":"CreateEvent","actor":{"id":10810283,"login":"direwolf-github","display_login":"direwolf-github","gravatar_id":"","url":"https://api.github.com/users/direwolf-github","avatar_url":"https://avatars.githubusercontent.com/u/10810283?"},"repo":{"id":355606000,"name":"direwolf-github/ephemeral-ci-4ac1a4fa","url":"https://api.github.com/repos/direwolf-github/ephemeral-ci-4ac1a4fa"},"payload":{"ref":"branch-d198ce0b","ref_type":"branch","master_branch":"master","description":null,"pusher_type":"user"},"public":true,"created_at":"2021-04-07T16:04:53Z"},{"id":"15850120572","type":"PullRequestEvent","actor":{"id":6329406,"login":"Babacooll","display_login":"Babacooll","gravatar_id":"","url":"https://api.github.com/users/Babacooll"," ...

# %% [markdown]
# ## Custom Headers

# %% [markdown]
# If you’d like to add HTTP headers to a request, simply pass in a dict to the headers parameter.

# %%
url = 'https://api.github.com/some/endpoint'
headers = {'user-agent': 'my-app/0.0.1'}

# %%
r = requests.get(url, headers=headers)

# %% [markdown]
# ## More complicated POST requests

# %% [markdown]
# Typically, you want to send some form-encoded data — much like an HTML form. To do this, simply pass a dictionary to the data argument. Your dictionary of data will automatically be form-encoded when the request is made

# %%
payload = {'key1': 'value1', 'key2': 'value2'}

# %%
r = requests.post("https://httpbin.org/post", data=payload)

# %%
print(r.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "key1": "value1",
#     "key2": "value2"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "23",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.22.0",
#     "X-Amzn-Trace-Id": "Root=1-606dd965-5feeaabf69c8809e79220c3c"
#   },
#   "json": null,
#   "origin": "111.249.52.205",
#   "url": "https://httpbin.org/post"
# }

# %% [markdown]
# The data argument can also have multiple values for each key. This can be done by making data either a list of tuples or a dictionary with lists as values. This is particularly useful when the form has multiple elements that use the same key

# %%
payload_tuples = [('key1', 'value1'), ('key1', 'value2')]
r1 = requests.post('https://httpbin.org/post', data=payload_tuples)

# %%
print(r1.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "key1": [
#       "value1",
#       "value2"
#     ]
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "23",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.22.0",
#     "X-Amzn-Trace-Id": "Root=1-606dd967-66e35fa62f7bd3f477d6bf1f"
#   },
#   "json": null,
#   "origin": "111.249.52.205",
#   "url": "https://httpbin.org/post"
# }

# %%
payload_dict = {'key1': ['value1', 'value2']}
r2 = requests.post('https://httpbin.org/post', data=payload_dict)

# %%
print(r2.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "key1": [
#       "value1",
#       "value2"
#     ]
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "23",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.22.0",
#     "X-Amzn-Trace-Id": "Root=1-606dd969-01b47dc01946d7e565346b3e"
#   },
#   "json": null,
#   "origin": "111.249.52.205",
#   "url": "https://httpbin.org/post"
# }

# %% [markdown]
# ## Response Status Codes

# %% [markdown]
# We can check the response status code

# %%
r = requests.get('https://httpbin.org/get')
r.status_code
# Out:
# 200

# %% [markdown]
# Requests also comes with a built-in status code lookup object for easy reference

# %%
r.status_code == requests.codes.ok
# Out:
# True

# %% [markdown]
# If we made a bad request (a 4XX client error or 5XX server error response), we can raise it with Response.raise_for_status()

# %%
bad_r = requests.get('https://httpbin.org/status/404')
bad_r.status_code
# Out:
# 404

# %%
bad_r.raise_for_status()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-27-6039039840f0> in <module>
# ----> 1 bad_r.raise_for_status()
#
# ~/Documents/anaconda3/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     938
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#     942     def close(self):
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://httpbin.org/status/404

# %% [markdown]
# But, since our status_code for r was 200, when we call raise_for_status( ) we get:

# %%
r.raise_for_status() # None

# %% [markdown]
# ## Response Headers

# %% [markdown]
# We can view the server’s response headers using a Python dictionary:

# %% [markdown]
# The dictionary is special, though: it’s made just for HTTP headers.

# %%
r.headers
# Out:
# {'Date': 'Wed, 07 Apr 2021 16:10:20 GMT', 'Content-Type': 'application/json', 'Content-Length': '308', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}

# %% [markdown]
# ## Cookies

# %% [markdown]
# To send your own cookies to the server, you can use the cookies parameter

# %%
url = 'https://httpbin.org/cookies'
cookies = dict(cookies_are='working')

# %%
r = requests.get(url, cookies=cookies)

# %%
r.text
# Out:
# '{\n  "cookies": {\n    "cookies_are": "working"\n  }\n}\n'

# %% [markdown]
# Cookies are returned in a RequestsCookieJar, which acts like a dict but also offers a more complete interface, suitable for use over multiple domains or paths. Cookie jars can also be passed in to requests:

# %%
jar = requests.cookies.RequestsCookieJar()
jar.set('tasty_cookie', 'yum', domain='httpbin.org', path='/cookies')
jar.set('gross_cookie', 'blech', domain='httpbin.org', path='/elsewhere')
url = 'https://httpbin.org/cookies'
r = requests.get(url, cookies=jar)
r.text
# Out:
# '{\n  "cookies": {\n    "tasty_cookie": "yum"\n  }\n}\n'

# %% [markdown]
# ## Redirection and History

# %% [markdown]
# By default Requests will perform location redirection for all verbs except HEAD.

# %% [markdown]
# We can use the history property of the Response object to track redirection.

# %% [markdown]
# The Response.history list contains the Response objects that were created in order to complete the request. The list is sorted from the oldest to the most recent response

# %%
r = requests.get('http://github.com/')

# %%
r.url
# Out:
# 'https://github.com/'

# %%
r.status_code
# Out:
# 200

# %%
r.history
# Out:
# [<Response [301]>]

# %% [markdown]
# You can disable redirection handling with the allow_redirects parameter:

# %%
r = requests.get('http://github.com/', allow_redirects=False)

# %%
r.status_code
# Out:
# 301

# %%
r.history
# Out:
# []

# %% [markdown]
# ## Timeouts

# %% [markdown]
# You can tell Requests to stop waiting for a response after a given number of seconds with the timeout parameter. Nearly all production code should use this parameter in nearly all requests. Failure to do so can cause your program to hang indefinitely

# %%
requests.get('https://github.com/', timeout=1)
# Out:
# <Response [200]>

# %% [markdown]
# ## Example 1 :  Yahoo! Shopping (Get Method)

# %%
from urllib.parse import quote
query = input("Please input search items：")
url = "https://tw.search.buy.yahoo.com/search/shopping/product?p=" + quote(query)
#https://tw.search.buy.yahoo.com/search/shopping/product?p=%E8%80%B3%E6%A9%9F
res = requests.get(url)
print(res.url)
# Out:
# Please input search items：耳機
# https://tw.buy.yahoo.com/search/product?p=%E8%80%B3%E6%A9%9F

# %%
res.text
# Out:
# '<!DOCTYPE html><html><head><meta http-equiv="content-type" content="text/html; charset=utf-8"/><title>耳機 - 優惠推薦 - 2021年4月 | Yahoo奇摩購物中心</title><meta name="viewport" content="width=device-width,initial-scale=1,minimum-scale=1.0,maximum-scale=1.0,user-scalable=no"/><meta name="application-name" content="Yahoo奇摩購物中心"/><meta name="description" content="在Yahoo奇摩購物中心找到5173筆耳機商品，其中包含了手機/相機/耳機/穿戴,電腦/電競/遊戲/週邊,機車/導航/汽車百貨等類型的耳機商品，數十萬件商品，品質生活盡在雅虎購物"/><meta property="og:title" content="耳機 - 優惠推薦 - 2021年4月 | Yahoo奇摩購物中心"/><meta property="og:type" content="website"/><meta property="og:url" content="https://tw.buy.yahoo.com/search/product?kw=%E8%80%B3%E6%A9%9F&amp;p=%E8%80%B3%E6%A9%9F"/><meta property="og:description" content="在Yahoo奇摩購物中心找到5173筆耳機商品，其中包含了手機/相機/耳機/穿戴,電腦/電競/遊戲/週邊,機車/導航/汽車百貨等類型的耳機商品，數十萬件商品，品質生活盡在雅虎購物"/><meta property="og:image" content="https://s.yimg.com/zp/MerchandiseImages/59902A0668-Gd-8856722.jpg"/><meta property="og:image:secure_url" content="https://s.yimg.com/zp/MerchandiseImages/59902A0668-Gd-8856722.jpg"/><meta property="og:locale" content="zh_TW"/><meta property="og:site_name" content="Yahoo奇摩購物中心"/><meta property="al:android:url" content="yecshopping://tw.buy.yahoo.com/search/product?kw=%E8%80%B3%E6%A9%9F&amp;p=%E8%80%B3%E6%A9%9F"/><meta property="al:android:package" content="com.yahoo.mobile.client.android.ecshopping"/><meta property="al:android:app_name" content="Yahoo奇摩購物中心"/><meta property="al:android:class" content="zh_TW"/><meta property="al:ios:app_store_id" content="1061577845"/><meta property="al:ios:app_name" content="Yahoo奇摩購物中心"/><meta property="al:ios:url" content="yecshopping://tw.buy.yahoo.com/search/product?kw=%E8%80%B3%E6%A9%9F&amp;p=%E8%80%B3%E6%A9%9F"/><meta property="al:web:should_fallback" content="true"/><meta name="oath:guce:product-eu" content="false"/><meta name="oath:guce:consent-host" content="guce.yahoo.com"/><meta name="oath:guce:locale" content="zh-Hant-TW"/><meta name="oath:guce:inline-consent" content="true"/><link rel="preconnect" href="https://s.yimg.com"/><link rel="preconnect" href="https://www.google.com"/><link rel="preconnect" href="https://www.google.com.tw"/><link rel="preconnect" href="https://ampcid.google.com"/><link rel="preconnect" href="https://ampcid.google.com.tw"/><link rel="preconnect" href="https://www.google-analytics.com"/><link rel="preconnect" href="https://stats.g.doubleclick.net"/><script defer="" src="https://s.yimg.com/oa/guce.js"></script><script>gtmDataLayer = [{"contentGroup":"search","pageType":"search_result"}]</script><script>\n        (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push(\n        {\'gtm.start\': new Date().getTime(),event:\'gtm.js\'}\n        );var f=d.getElementsByTagName(s)[0],\n        j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n        \'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n        })(window,document,\'script\',\'gtmDataLayer\',\'GTM-WJ5JQR4\');</script><script defer="" src="https://www.google-analytics.com/analytics.js"></script><script defer="" src="https://www.googletagmanager.com/gtag/js?id=UA-71726228-1"></script><script defer="" src="/rapidworker-1.2.js"></script><script defer="" src="https://s.yimg.com/ss/rapid3.js"></script><script defer="" src="https://s.yimg.com/zq/searchv3/core.eb240148fa1781f147c7.js"></script><script defer="" src="https://s.yimg.com/zq/searchv3/vendor.917d88617babf871cb83.js"></script><script defer="" src="https://s.yimg.com/zq/searchv3/shoppingSearch.6df26411651cfe6b4757.js"></script><link rel="amphtml" href="https://tw.buy.yahoo.com/amp/search/product?p=%E8%80%B3%E6%A9%9F"/><link rel="canonical" href="https://tw.buy.yahoo.com/search/product?p=%E8%80%B3%E6%A9%9F"/><link rel="stylesheet" href="https://s.yimg.com/zq/searchv3/shoppingSearch.d1a6e35d8853d214c416.css"/><script type="application/ld+json">[{"@context":"http://schema.org","@type":"itemList","itemListElement":[{"@type":"ListItem","position":0,"url":"https://tw.buy.yahoo ...

# %% [markdown]
# ## Example 2: Taiwan High Speed Rail (Post Method)

# %%
import requests

url = 'https://m.thsrc.com.tw/TimeTable/Search'
thsrc = {
    'SearchType':'S',
    'Lang':'TW',
    'StartStation': 'NanGang',
    'EndStation': 'ZuoYing',
    'OutWardSearchDate': '2021/04/08',
    'OutWardSearchTime': '19:00',
    'ReturnSearchDate': '2021/04/08',
    'ReturnSearchTime': '00:00'
}

res = requests.post(url, data = thsrc)

# %%
print(res.text)
# Out:
# {"success":true,"data":{"DepartureTable":{"Title":{"StartStationName":"南港","EndStationName":"左營","TitleSplit1":"2021/04/08(四) 19:00","TitleSplit2":"2021/04/08(四)"},"TrainItem":[{"TrainNumber":"0803","DepartureTime":"06:15","DestinationTime":"08:40","Duration":"02:25","NonReservedCar":"9-12","Discount":[{"Id":"9973b559-8279-4bf4-90be-601f7973a39f","Name":"25人團體","Value":"7折","Color":"#1685e4","Discount":"70"},{"Id":"68d9fc7b-7330-44c2-962a-74bc47d2ee8a","Name":"大學生","Value":"75折","Color":"#e45916","Discount":"75"},{"Id":"40863ff1-a16c-4da1-8af7-c1f8991627f3","Name":"校外教學","Value":"4/7折","Color":"#ffcc00","Discount":"40|70"}],"Note":"","Sequence":0,"StationInfo":[{"StationNo":"01","StationName":"南港","DepartureTime":"06:15","Show":true,"ColorClass":"orange"},{"StationNo":"02","StationName":"台北","DepartureTime":"06:26","Show":true,"ColorClass":"purple"},{"StationNo":"03","StationName":"板橋","DepartureTime":"06:34","Show":true,"ColorClass":"dark_green"},{"StationNo":"04","StationName":"桃園","DepartureTime":"06:49","Show":true,"ColorClass":"light_green"},{"StationNo":"05","StationName":"新竹","DepartureTime":"07:02","Show":true,"ColorClass":"gray"},{"StationNo":"06","StationName":"苗栗","DepartureTime":"07:13","Show":true,"ColorClass":"sky_blue"},{"StationNo":"07","StationName":"台中","DepartureTime":"07:32","Show":true,"ColorClass":"pink"},{"StationNo":"08","StationName":"彰化","DepartureTime":"07:45","Show":true,"ColorClass":"red"},{"StationNo":"09","StationName":"雲林","DepartureTime":"07:56","Show":true,"ColorClass":"dark_blue"},{"StationNo":"10","StationName":"嘉義","DepartureTime":"08:10","Show":true,"ColorClass":"yellow"},{"StationNo":"11","StationName":"台南","DepartureTime":"08:28","Show":true,"ColorClass":"brown"},{"StationNo":"12","StationName":"左營","DepartureTime":"08:40","Show":true,"ColorClass":"blue"}],"IsCrossNight":false,"RunDate":"2021/04/08","DepartureTime_Order":"06:15","DestinationTime_Order":"08:40","DiscountWord":null},{"TrainNumber":"0603","DepartureTime":"06:40","DestinationTime":"08:50","Duration":"02:10","NonReservedCar":"9-12","Discount":[],"Note":"","Sequence":1,"StationInfo":[{"StationNo":"01","StationName":"南港","DepartureTime":"06:40","Show":true,"ColorClass":"orange"},{"StationNo":"02","StationName":"台北","DepartureTime":"06:51","Show":true,"ColorClass":"purple"},{"StationNo":"03","StationName":"板橋","DepartureTime":"07:00","Show":true,"ColorClass":"dark_green"},{"StationNo":"04","StationName":"桃園","DepartureTime":"07:15","Show":true,"ColorClass":"light_green"},{"StationNo":"05","StationName":"新竹","DepartureTime":"07:27","Show":true,"ColorClass":"gray"},{"StationNo":"06","StationName":"苗栗","DepartureTime":"","Show":false,"ColorClass":"sky_blue"},{"StationNo":"07","StationName":"台中","DepartureTime":"07:53","Show":true,"ColorClass":"pink"},{"StationNo":"08","StationName":"彰化","DepartureTime":"","Show":false,"ColorClass":"red"},{"StationNo":"09","StationName":"雲林","DepartureTime":"","Show":false,"ColorClass":"dark_blue"},{"StationNo":"10","StationName":"嘉義","DepartureTime":"08:19","Show":true,"ColorClass":"yellow"},{"StationNo":"11","StationName":"台南","DepartureTime":"08:38","Show":true,"ColorClass":"brown"},{"StationNo":"12","StationName":"左營","DepartureTime":"08:50","Show":true,"ColorClass":"blue"}],"IsCrossNight":false,"RunDate":"2021/04/08","DepartureTime_Order":"06:40","DestinationTime_Order":"08:50","DiscountWord":null},{"TrainNumber":"0805","DepartureTime":"07:00","DestinationTime":"09:25","Duration":"02:25","NonReservedCar":"9-12","Discount":[],"Note":"","Sequence":2,"StationInfo":[{"StationNo":"01","StationName":"南港","DepartureTime":"07:00","Show":true,"ColorClass":"orange"},{"StationNo":"02","StationName":"台北","DepartureTime":"07:11","Show":true,"ColorClass":"purple"},{"StationNo":"03","StationName":"板橋","DepartureTime":"07:19","Show":true,"ColorClass":"dark_green"},{"StationNo":"04","StationName":"桃園","DepartureTime":"07:34","Show":true,"ColorClass":"light_green"},{"StationNo":"05","StationName":"新竹","Departure ...

# %% [markdown]
# # BeautifulSoup

# %% [markdown]
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %% [markdown]
# Beautiful Soup is a Python library for pulling data out of HTML and XML files. It works with your favorite parser to provide idiomatic ways of navigating, searching, and modifying the parse tree.

# %% [markdown]
# Here’s an HTML document. It’s part of a story from Alice in Wonderland

# %%
html_doc = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# %% [markdown]
# Running the “three sisters” document through Beautiful Soup gives us a BeautifulSoup object, which represents the document as a nested data structure

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_doc, 'html.parser')

print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %% [markdown]
# Here are some simple ways to navigate that data structure

# %%
soup.title
# Out:
# <title>The Dormouse's story</title>

# %%
soup.title.name
# Out:
# 'title'

# %%
soup.title.string
# Out:
# "The Dormouse's story"

# %%
soup.title.parent.name
# Out:
# 'head'

# %%
soup.p
# Out:
# <p class="title"><b>The Dormouse's story</b></p>

# %%
soup.p['class']
# Out:
# ['title']

# %%
soup.a
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
soup.find_all('a')
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
soup.find(id="link3")
# Out:
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>

# %% [markdown]
# One common task is extracting all the URLs found within a page’s <a> tags

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# http://example.com/elsie
# http://example.com/lacie
# http://example.com/tillie

# %% [markdown]
# Another common task is extracting all the text from a page

# %%
print(soup.get_text())
# Out:
# The Dormouse's story
#
# The Dormouse's story
# Once upon a time there were three little sisters; and their names were
# Elsie,
# Lacie and
# Tillie;
# and they lived at the bottom of a well.
# ...

# %% [markdown]
# ## Making the Soup

# %% [markdown]
# To parse a document, pass it into the BeautifulSoup constructor. You can pass in a string or an open filehandle

# %%
from bs4 import BeautifulSoup

#with open("index.html") as fp:
#    soup = BeautifulSoup(fp)

soup = BeautifulSoup("<html>data</html>")

# %% [markdown]
# Beautiful Soup then parses the document using the best available parser. It will use an HTML parser unless you specifically tell it to use an XML parser.

# %% [markdown]
# ## Kinds of Objects

# %% [markdown]
# Beautiful Soup transforms a complex HTML document into a complex tree of Python objects.

# %% [markdown]
# But you’ll only ever have to deal with about four kinds of objects:
# * Tag
# * NavigableString
# * BeautifulSoup
# * Comment

# %% [markdown]
# ### Tag

# %% [markdown]
# A Tag object corresponds to an XML or HTML tag in the original document

# %%
soup = BeautifulSoup('<b class="boldest">Extremely bold</b>')
tag = soup.b
type(tag)
# Out:
# bs4.element.Tag

# %% [markdown]
# The most important features of a tag are its name and attributes.

# %% [markdown]
# #### Name

# %% [markdown]
# Every tag has a name, accessible as .name

# %%
tag.name
# Out:
# 'b'

# %% [markdown]
# If you change a tag’s name, the change will be reflected in any HTML markup generated by Beautiful Soup

# %%
tag.name = "blockquote"
tag
# Out:
# <blockquote class="boldest">Extremely bold</blockquote>

# %% [markdown]
# #### Attribute

# %% [markdown]
# A tag may have any number of attributes. You can access a tag’s attributes by treating the tag like a dictionary

# %%
soup = BeautifulSoup('<b id="boldest"></b>')
tag = soup.b

# %%
tag['id']
# Out:
# 'boldest'

# %% [markdown]
# You can access that dictionary directly as .attrs

# %%
tag.attrs
# Out:
# {'id': 'boldest'}

# %% [markdown]
# You can add, remove, and modify a tag’s attributes. Again, this is done by treating the tag as a dictionary

# %%
tag['id'] = 'verybold'
tag['another-attribute'] = 1
tag
# Out:
# <b another-attribute="1" id="verybold"></b>

# %%
del tag['id']
del tag['another-attribute']
tag
# Out:
# <b></b>

# %%
tag['id']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-b7d877d82646> in <module>
# ----> 1 tag['id']
#
# ~/Documents/anaconda3/lib/python3.7/site-packages/bs4/element.py in __getitem__(self, key)
#    1319         """tag[key] returns the value of the 'key' attribute for the Tag,
#    1320         and throws an exception if it's not there."""
# -> 1321         return self.attrs[key]
#    1322
#    1323     def __iter__(self):
#
# KeyError: 'id'

# %%
print(tag.get('id'))
# Out:
# None

# %% [markdown]
# #### Multi-valued attributes

# %% [markdown]
# The most common multi-valued attribute is class (that is, a tag can have more than one CSS class). Others include rel, rev, accept-charset, headers, and accesskey.

# %% [markdown]
# Beautiful Soup presents the value(s) of a multi-valued attribute as a list

# %%
css_soup = BeautifulSoup('<p class="body"></p>')
css_soup.p['class']
# Out:
# ['body']

# %%
css_soup = BeautifulSoup('<p class="body strikeout"></p>')
css_soup.p['class']
# Out:
# ['body', 'strikeout']

# %% [markdown]
# If an attribute looks like it has more than one value, but it’s not a multi-valued attribute as defined by any version of the HTML standard, Beautiful Soup will leave the attribute alone

# %%
id_soup = BeautifulSoup('<p id="my id"></p>')
id_soup.p['id']
# Out:
# 'my id'

# %% [markdown]
# When you turn a tag back into a string, multiple attribute values are consolidated

# %%
rel_soup = BeautifulSoup('<p>Back to the <a rel="index">homepage</a></p>')
rel_soup.a['rel']
# Out:
# ['index']

# %%
rel_soup.a['rel'] = ['index', 'contents']

# %%
print(rel_soup.p)
# Out:
# <p>Back to the <a rel="index contents">homepage</a></p>

# %% [markdown]
# You can disable this by passing multi_valued_attributes=None as a keyword argument into the BeautifulSoup constructor

# %%
no_list_soup = BeautifulSoup('<p class="body strikeout"></p>', 'html', multi_valued_attributes=None)
no_list_soup.p['class']
# Out:
# 'body strikeout'

# %% [markdown]
# You can use `get_attribute_list to get a value that’s always a list, whether or not it’s a multi-valued atribute

# %%
id_soup.p.get_attribute_list('id')
# Out:
# ['my id']

# %% [markdown]
# If you parse a document as XML, there are no multi-valued attributes

# %%
xml_soup = BeautifulSoup('<p class="body strikeout"></p>', 'xml')
xml_soup.p['class']
# Out:
# 'body strikeout'

# %% [markdown]
# Again, you can configure this using the multi_valued_attributes argument

# %%
class_is_multi= { '*' : 'class'}
xml_soup = BeautifulSoup('<p class="body strikeout"></p>', 'xml', multi_valued_attributes=class_is_multi)
xml_soup.p['class']
# Out:
# ['body', 'strikeout']

# %% [markdown]
# You probably won’t need to do this, but if you do, use the defaults as a guide. They implement the rules described in the HTML specification

# %%
from bs4.builder import builder_registry
builder_registry.lookup('html').DEFAULT_CDATA_LIST_ATTRIBUTES
# Out:
# {'*': ['class', 'accesskey', 'dropzone'],
#  'a': ['rel', 'rev'],
#  'link': ['rel', 'rev'],
#  'td': ['headers'],
#  'th': ['headers'],
#  'form': ['accept-charset'],
#  'object': ['archive'],
#  'area': ['rel'],
#  'icon': ['sizes'],
#  'iframe': ['sandbox'],
#  'output': ['for']}

# %% [markdown]
# ### NavigableString

# %% [markdown]
# A string corresponds to a bit of text within a tag. Beautiful Soup uses the NavigableString class to contain these bits of text

# %%
tag = BeautifulSoup('<b class="boldest">Extremely bold</b>')
tag.string
# Out:
# 'Extremely bold'

# %%
type(tag.string)
# Out:
# bs4.element.NavigableString

# %% [markdown]
# A NavigableString is just like a Python Unicode string, except that it also supports some of the features described in Navigating the tree and Searching the tree.

# %% [markdown]
# You can’t edit a string in place, but you can replace one string with another, using replace_with( )

# %%
tag.string.replace_with("No longer bold")
tag
# Out:
# <html><body><b class="boldest">No longer bold</b></body></html>

# %% [markdown]
# ### BeautifulSoup

# %% [markdown]
# The BeautifulSoup object represents the parsed document as a whole. For most purposes, you can treat it as a Tag object. This means it supports most of the methods described in Navigating the tree and Searching the tree.

# %%
doc = BeautifulSoup("<document><content/>INSERT FOOTER HERE</document", "xml")
footer = BeautifulSoup("<footer>Here's the footer</footer>", "xml")
doc.find(text="INSERT FOOTER HERE").replace_with(footer)
# Out:
# 'INSERT FOOTER HERE'

# %%
print(doc)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <document><content/><footer>Here's the footer</footer></document>

# %% [markdown]
# ### Comments

# %% [markdown]
# Tag, NavigableString, and BeautifulSoup cover almost everything you’ll see in an HTML or XML file, but there are a few leftover bits. The main one you’ll probably encounter is the comment

# %%
markup = "<b><!--Hey, buddy. Want to buy a used parser?--></b>"
soup = BeautifulSoup(markup)
comment = soup.b.string

# %%
type(comment)
# Out:
# bs4.element.Comment

# %% [markdown]
# The Comment object is just a special type of NavigableString

# %%
comment
# Out:
# 'Hey, buddy. Want to buy a used parser?'

# %% [markdown]
# But when it appears as part of an HTML document, a Comment is displayed with special formatting

# %%
print(soup.b.prettify())
# Out:
# <b>
#  <!--Hey, buddy. Want to buy a used parser?-->
# </b>

# %% [markdown]
# ## Navigating the tree

# %% [markdown]
# Here’s the “Three sisters” HTML document again

# %%
html_doc = """<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>"""

from bs4 import BeautifulSoup
soup = BeautifulSoup(html_doc, 'html.parser')

# %% [markdown]
# ### Going down

# %% [markdown]
# Tags may contain strings and other tags. These elements are the tag’s children. Beautiful Soup provides a lot of different attributes for navigating and iterating over a tag’s children.

# %% [markdown]
# Note that Beautiful Soup strings don’t support any of these attributes, because a string can’t have children.

# %% [markdown]
# #### Navigating using tag names

# %% [markdown]
# The simplest way to navigate the parse tree is to say the name of the tag you want.

# %%
soup.head
# Out:
# <head><title>The Dormouse's story</title></head>

# %%
soup.title
# Out:
# <title>The Dormouse's story</title>

# %% [markdown]
# You can do use this trick again and again to zoom in on a certain part of the parse tree. This code gets the first < b> tag beneath the < body> tag

# %%
soup.body.b
# Out:
# <b>The Dormouse's story</b>

# %% [markdown]
# Using a tag name as an attribute will give you only the first tag by that name

# %%
soup.a
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %% [markdown]
# If you need to get all the < a> tags, or anything more complicated than the first tag with a certain name, you’ll need to use one of the methods described in Searching the tree, such as find_all( )

# %%
soup.find_all('a')
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %% [markdown]
# A tag’s children are available in a list called .contents

# %%
head_tag = soup.head
head_tag
# Out:
# <head><title>The Dormouse's story</title></head>

# %%
head_tag.contents
# Out:
# [<title>The Dormouse's story</title>]

# %%
title_tag = head_tag.contents[0]
title_tag
# Out:
# <title>The Dormouse's story</title>

# %%
title_tag.contents
# Out:
# ["The Dormouse's story"]

# %% [markdown]
# The BeautifulSoup object itself has children. In this case, the < html> tag is the child of the BeautifulSoup object

# %%
len(soup.contents)
# Out:
# 1

# %%
soup.contents[0].name
# Out:
# 'html'

# %% [markdown]
# A string does not have .contents, because it can’t contain anything

# %%
text = title_tag.contents[0]
text.contents
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-102-4aa60c348c32> in <module>
#       1 text = title_tag.contents[0]
# ----> 2 text.contents
#
# ~/Documents/anaconda3/lib/python3.7/site-packages/bs4/element.py in __getattr__(self, attr)
#     869             raise AttributeError(
#     870                 "'%s' object has no attribute '%s'" % (
# --> 871                     self.__class__.__name__, attr))
#     872
#     873     def output_ready(self, formatter="minimal"):
#
# AttributeError: 'NavigableString' object has no attribute 'contents'

# %% [markdown]
# Instead of getting them as a list, you can iterate over a tag’s children using the .children generator

# %%
for child in title_tag.children:
    print(child)
# Out:
# The Dormouse's story

# %% [markdown]
# The .contents and .children attributes only consider a tag’s direct children. For instance, the < head> tag has a single direct child–the < title> tag

# %%
head_tag.contents
# Out:
# [<title>The Dormouse's story</title>]

# %% [markdown]
# But the < title> tag itself has a child: the string “The Dormouse’s story”. There’s a sense in which that string is also a child of the < head> tag. The .descendants attribute lets you iterate over all of a tag’s children, recursively: its direct children, the children of its direct children, and so on

# %%
for child in head_tag.descendants:
    print(child)
# Out:
# <title>The Dormouse's story</title>
# The Dormouse's story

# %% [markdown]
# The < head> tag has only one child, but it has two descendants: the < title> tag and the < title> tag’s child. The BeautifulSoup object only has one direct child (the < html> tag), but it has a whole lot of descendants

# %%
len(list(soup.children))
# Out:
# 1

# %%
len(list(soup.descendants))
# Out:
# 25

# %% [markdown]
# If a tag has only one child, and that child is a NavigableString, the child is made available as .string

# %%
title_tag.string
# Out:
# "The Dormouse's story"

# %% [markdown]
# If a tag’s only child is another tag, and that tag has a .string, then the parent tag is considered to have the same .string as its child

# %%
head_tag.contents
# Out:
# [<title>The Dormouse's story</title>]

# %%
head_tag.string
# Out:
# "The Dormouse's story"

# %% [markdown]
# If a tag contains more than one thing, then it’s not clear what .string should refer to, so .string is defined to be None

# %%
print(soup.html.string)
# Out:
# None

# %% [markdown]
# If there’s more than one thing inside a tag, you can still look at just the strings. Use the .strings generator

# %%
for string in soup.strings:
    print(repr(string))
# Out:
# "The Dormouse's story"
# '\n'
# '\n'
# "The Dormouse's story"
# '\n'
# 'Once upon a time there were three little sisters; and their names were\n'
# 'Elsie'
# ',\n'
# 'Lacie'
# ' and\n'
# 'Tillie'
# ';\nand they lived at the bottom of a well.'
# '\n'
# '...'

# %% [markdown]
# These strings tend to have a lot of extra whitespace, which you can remove by using the .stripped_strings generator instead

# %%
for string in soup.stripped_strings:
    print(repr(string))
# Out:
# "The Dormouse's story"
# "The Dormouse's story"
# 'Once upon a time there were three little sisters; and their names were'
# 'Elsie'
# ','
# 'Lacie'
# 'and'
# 'Tillie'
# ';\nand they lived at the bottom of a well.'
# '...'

# %% [markdown]
# ### Going Up

# %% [markdown]
# Continuing the “family tree” analogy, every tag and every string has a parent: the tag that contains it

# %% [markdown]
# You can access an element’s parent with the .parent attribute. In the example “three sisters” document, the < head> tag is the parent of the < title> tag

# %%
title_tag = soup.title
title_tag
# Out:
# <title>The Dormouse's story</title>

# %%
title_tag.parent
# Out:
# <head><title>The Dormouse's story</title></head>

# %% [markdown]
# The title string itself has a parent: the < title> tag that contains it

# %%
title_tag.string.parent
# Out:
# <title>The Dormouse's story</title>

# %% [markdown]
# The parent of a top-level tag like <html> is the BeautifulSoup object itself

# %%
html_tag = soup.html
type(html_tag.parent)
# Out:
# bs4.BeautifulSoup

# %% [markdown]
# And the .parent of a BeautifulSoup object is defined as None

# %%
print(soup.parent)
# Out:
# None

# %% [markdown]
# You can iterate over all of an element’s parents with .parents. This example uses .parents to travel from an < a> tag buried deep within the document, to the very top of the document

# %%
link = soup.a
link
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
for parent in link.parents:
    if parent is None:
        print(parent)
    else:
        print(parent.name)
# Out:
# p
# body
# html
# [document]

# %% [markdown]
# ### Going sideways

# %% [markdown]
# Consider a simple document like this

# %%
sibling_soup = BeautifulSoup("<a><b>text1</b><c>text2</c></b></a>")
print(sibling_soup.prettify())
# Out:
# <html>
#  <body>
#   <a>
#    <b>
#     text1
#    </b>
#    <c>
#     text2
#    </c>
#   </a>
#  </body>
# </html>

# %% [markdown]
# The < b> tag and the < c> tag are at the same level: they’re both direct children of the same tag. We call them siblings. When a document is pretty-printed, siblings show up at the same indentation level. You can also use this relationship in the code you write.

# %% [markdown]
# You can use .next_sibling and .previous_sibling to navigate between page elements that are on the same level of the parse tree

# %%
sibling_soup.b.next_sibling
# Out:
# <c>text2</c>

# %%
sibling_soup.c.previous_sibling
# Out:
# <b>text1</b>

# %% [markdown]
# The < b> tag has a .next_sibling, but no .previous_sibling, because there’s nothing before the < b> tag on the same level of the tree. For the same reason, the < c> tag has a .previous_sibling but no .next_sibling

# %%
print(sibling_soup.b.previous_sibling)
# Out:
# None

# %%
print(sibling_soup.c.next_sibling)
# Out:
# None

# %% [markdown]
# The strings “text1” and “text2” are not siblings, because they don’t have the same parent

# %%
sibling_soup.b.string
# Out:
# 'text1'

# %%
print(sibling_soup.b.string.next_sibling)
# Out:
# None

# %% [markdown]
# In real documents, the .next_sibling or .previous_sibling of a tag will usually be a string containing whitespace. Going back to the “three sisters” document

# %% [raw]
# <a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>
# <a href="http://example.com/lacie" class="sister" id="link2">Lacie</a>
# <a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>

# %% [markdown]
# You might think that the .next_sibling of the first < a> tag would be the second < a> tag. But actually, it’s a string: the comma and newline that separate the first < a> tag from the second

# %%
link = soup.a
link
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
link.next_sibling
# Out:
# ',\n'

# %% [markdown]
# The second < a> tag is actually the .next_sibling of the comma

# %%
link.next_sibling.next_sibling
# Out:
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>

# %% [markdown]
# You can iterate over a tag’s siblings with .next_siblings or .previous_siblings

# %%
for sibling in soup.a.next_siblings:
    print(repr(sibling))
# Out:
# ',\n'
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>
# ' and\n'
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>
# ';\nand they lived at the bottom of a well.'

# %%
for sibling in soup.find(id="link3").previous_siblings:
    print(repr(sibling))
# Out:
# ' and\n'
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>
# ',\n'
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
# 'Once upon a time there were three little sisters; and their names were\n'

# %% [markdown]
# ### Going back and forth

# %% [markdown]
# Take a look at the beginning of the “three sisters” document

# %% [raw]
# <html><head><title>The Dormouse's story</title></head>
# <p class="title"><b>The Dormouse's story</b></p>

# %% [markdown]
# An HTML parser takes this string of characters and turns it into a series of events: “open an < html> tag”, “open a < head> tag”, “open a < title> tag”, “add a string”, “close the < title> tag”, “open a < p> tag”, and so on. Beautiful Soup offers tools for reconstructing the initial parse of the document

# %% [markdown]
# The .next_element attribute of a string or tag points to whatever was parsed immediately afterwards. It might be the same as .next_sibling, but it’s usually drastically different.

# %% [markdown]
# Here’s the final < a> tag in the “three sisters” document. Its .next_sibling is a string: the conclusion of the sentence that was interrupted by the start of the < a> tag.

# %%
last_a_tag = soup.find("a", id="link3")
last_a_tag
# Out:
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>

# %%
last_a_tag.next_sibling
# Out:
# ';\nand they lived at the bottom of a well.'

# %% [markdown]
# But the .next_element of that < a> tag, the thing that was parsed immediately after the < a> tag, is not the rest of that sentence: it’s the word “Tillie”

# %%
last_a_tag.next_element
# Out:
# 'Tillie'

# %% [markdown]
# The .previous_element attribute is the exact opposite of .next_element. It points to whatever element was parsed immediately before this one

# %%
last_a_tag.previous_element
# Out:
# ' and\n'

# %%
last_a_tag.previous_element.next_element
# Out:
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>

# %% [markdown]
# You can use these iterators to move forward or backward in the document as it was parsed

# %%
for element in last_a_tag.next_elements:
    print(repr(element))
# Out:
# 'Tillie'
# ';\nand they lived at the bottom of a well.'
# '\n'
# <p class="story">...</p>
# '...'

# %% [markdown]
# ## Searching the tree

# %% [markdown]
# Beautiful Soup defines a lot of methods for searching the parse tree, but they’re all very similar.

# %%
html_doc = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

from bs4 import BeautifulSoup
soup = BeautifulSoup(html_doc, 'html.parser')

# %% [markdown]
# ### Kinds of Filters

# %% [markdown]
# Before talking in detail about find_all( ) and similar methods, I want to show examples of different filters you can pass into these methods. These filters show up again and again, throughout the search API. You can use them to filter based on a tag’s name, on its attributes, on the text of a string, or on some combination of these.

# %% [markdown]
# #### A string

# %% [markdown]
# The simplest filter is a string. Pass a string to a search method and Beautiful Soup will perform a match against that exact string.

# %%
soup.find_all('b')
# Out:
# [<b>The Dormouse's story</b>]

# %% [markdown]
# #### A regular expression

# %% [markdown]
# If you pass in a regular expression object, Beautiful Soup will filter against that regular expression using its search( ) method.

# %%
import re
for tag in soup.find_all(re.compile("^b")):
    print(tag.name)
# Out:
# body
# b

# %%
for tag in soup.find_all(re.compile("t")):
    print(tag.name)
# Out:
# html
# title

# %% [markdown]
# #### A list

# %% [markdown]
# If you pass in a list, Beautiful Soup will allow a string match against any item in that list.

# %%
soup.find_all(["a", "b"])
# Out:
# [<b>The Dormouse's story</b>,
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %% [markdown]
# The value True matches everything it can

# %%
for tag in soup.find_all(True):
    print(tag.name)
# Out:
# html
# head
# title
# body
# p
# b
# p
# a
# a
# a
# p

# %% [markdown]
# #### A function

# %% [markdown]
# If none of the other matches work for you, define a function that takes an element as its only argument. The function should return True if the argument matches, and False otherwise.

# %%
def has_class_but_no_id(tag):
    return tag.has_attr('class') and not tag.has_attr('id')

# %%
soup.find_all(has_class_but_no_id)
# Out:
# [<p class="title"><b>The Dormouse's story</b></p>,
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>,
#  <p class="story">...</p>]

# %%
def not_lacie(href):
    return href and not re.compile("lacie").search(href)
soup.find_all(href=not_lacie)
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
from bs4 import NavigableString
def surrounded_by_strings(tag):
    return (isinstance(tag.next_element, NavigableString)
            and isinstance(tag.previous_element, NavigableString))

for tag in soup.find_all(surrounded_by_strings):
    print(tag.name)
# Out:
# body
# p
# a
# a
# a
# p

# %% [markdown]
# ### find_all( )

# %% [markdown]
# The find_all( ) method looks through a tag’s descendants and retrieves all descendants that match your filters.

# %%
soup.find_all("title")
# Out:
# [<title>The Dormouse's story</title>]

# %%
soup.find_all("p", "title")
# Out:
# [<p class="title"><b>The Dormouse's story</b></p>]

# %%
soup.find_all("a")
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
soup.find_all(id="link2")
# Out:
# [<a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>]

# %%
import re
soup.find(string=re.compile("sisters"))
# Out:
# 'Once upon a time there were three little sisters; and their names were\n'

# %% [markdown]
# * What does it mean to pass in a value for string, or id?
# * Why does find_all("p", "title") find a < p> tag with the CSS class “title”?

# %% [markdown]
# #### The name argument

# %% [markdown]
# Pass in a value for name and you’ll tell Beautiful Soup to only consider tags with certain names

# %%
soup.find_all("title")
# Out:
# [<title>The Dormouse's story</title>]

# %% [markdown]
# #### The keyword arguments

# %% [markdown]
# Any argument that’s not recognized will be turned into a filter on one of a tag’s attributes.

# %%
soup.find_all(id='link2')
# Out:
# [<a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>]

# %%
soup.find_all(href=re.compile("elsie"))
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>]

# %%
soup.find_all(id=True)
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
soup.find_all(href=re.compile("elsie"), id='link1')
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>]

# %% [markdown]
# #### The string argument

# %% [markdown]
# With string you can search for strings instead of tags

# %%
soup.find_all(string="Elsie")
# Out:
# ['Elsie']

# %%
soup.find_all(string=["Tillie", "Elsie", "Lacie"])
# Out:
# ['Elsie', 'Lacie', 'Tillie']

# %%
soup.find_all(string=re.compile("Dormouse"))
# Out:
# ["The Dormouse's story", "The Dormouse's story"]

# %%
def is_the_only_string_within_a_tag(s):
    """Return True if this string is the only child of its parent tag."""
    return (s == s.parent.string)

# %%
soup.find_all(string=is_the_only_string_within_a_tag)
# Out:
# ["The Dormouse's story",
#  "The Dormouse's story",
#  'Elsie',
#  'Lacie',
#  'Tillie',
#  '...']
